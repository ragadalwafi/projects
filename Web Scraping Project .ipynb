# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_Saudi_Arabia'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of largest companies in Saudi Arabia - Wikipedia</title>
# ...

# %%
table = soup.find_all('table')[1]
print(table)
# Out:
# <table class="wikitable sortable static-row-numbers static-row-header-text" style="text-align:left;">
# <tbody><tr>
# <th align="center">Forbes 2000 ranking
# </th>
# <th align="center">Name
# </th>
# <th align="center">Headquarters
# </th>
# <th align="center">Revenue <small>(billions  US$)</small>
# </th>
# <th align="center">Profit <small>(billions US$)</small>
# </th>
# <th align="center">Assets <small>(billions US$)</small>
# </th>
# <th align="center">Value <small>(billions US$)</small>
# </th>
# <th align="center">Industry
# </th></tr>
# <tr>
# <td>5
# </td>
# <td align="left"><a href="/wiki/Saudi_Aramco" title="Saudi Aramco">Saudi Aramco</a>
# </td>
# <td align="left">Dhahran
# </td>
# <td>329.8
# </td>
# <td>88.2
# </td>
# <td>398.3
# </td>
# <td>1,900
# </td>
# <td align="left"><a class="mw-redirect" href="/wiki/Oil_and_gas" title="Oil and gas">Oil and gas</a>
# </td></tr>
# <tr>
# <td>212
# </td>
# ...

# %%
world_title = table.find_all('th')

# %%
world_title
# Out:
# [<th align="center">Forbes 2000 ranking
#  </th>,
#  <th align="center">Name
#  </th>,
#  <th align="center">Headquarters
#  </th>,
#  <th align="center">Revenue <small>(billions  US$)</small>
#  </th>,
#  <th align="center">Profit <small>(billions US$)</small>
#  </th>,
#  <th align="center">Assets <small>(billions US$)</small>
#  </th>,
#  <th align="center">Value <small>(billions US$)</small>
#  </th>,
#  <th align="center">Industry
#  </th>]

# %%
world_table_titles = [title.text.strip() for title in world_title]
print(world_table_titles)
# Out:
# ['Forbes 2000 ranking', 'Name', 'Headquarters', 'Revenue (billions  US$)', 'Profit (billions US$)', 'Assets (billions US$)', 'Value (billions US$)', 'Industry']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_titles)
df
# Out:
# Empty DataFrame
# Columns: [Forbes 2000 ranking, Name, Headquarters, Revenue (billions  US$), Profit (billions US$), Assets (billions US$), Value (billions US$), Industry]
# Index: []

# %%
columns_name = table.find_all('tr')

# %%
for row in columns_name[1:]:
    row_data = row.find_all('td')
    singel_row_data = [data.text.strip() for data in row_data]
    length = len(df)
    df.loc[length] = singel_row_data

# %%
df
# Out:
#    Forbes 2000 ranking                       Name Headquarters  \
# 0                    5               Saudi Aramco      Dhahran
# 1                  212     Saudi Basic Industries       Riyadh
# 2                  315      Saudi Telecom Company       Riyadh
# 3                  396        Saudi National Bank       Riyadh
# 4                  473              Al-Rajhi Bank       Riyadh
# 5                  590  Saudi Electricity Company       Riyadh
# 6                  709                 Riyad Bank       Riyadh
# 7                  780      Samba Financial Group       Riyadh
# 8                  814         Saudi British Bank       Riyadh
# 9                  934        Banque Saudi Fransi       Riyadh
# 10                1013         Arab National Bank       Riyadh
# 11                1124                Alinma Bank       Riyadh
# 12                1508                     Maaden       Riyadh
# 13                1681                    Almarai       Riyadh
# ...

# %%
df.to_csv(r'C:\Users\hp\OneDrive\المستندات\Custom Office Templates\Companies.csv', index = False)
